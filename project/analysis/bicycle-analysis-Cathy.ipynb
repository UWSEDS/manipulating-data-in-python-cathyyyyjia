# %% [markdown]
# # <center> Data 515 Homework 1 </center>
# <center> Cathy Jia </center>

# %% [markdown]
# ## 1
# **Read the CSV file into a pandas dataframe. (1 pt)**

# %%
import pandas as pd
bicycle = pd.read_csv('../data/bicycle.csv')
bicycle.head(10)
# Out:
#                      Date  Fremont Bridge East Sidewalk  \
# 0  03/31/2019 11:00:00 PM                           6.0
# 1  03/31/2019 10:00:00 PM                           7.0
# 2  03/31/2019 09:00:00 PM                          18.0
# 3  03/31/2019 08:00:00 PM                          26.0
# 4  03/31/2019 07:00:00 PM                          30.0
# 5  03/31/2019 06:00:00 PM                          73.0
# 6  03/31/2019 05:00:00 PM                          99.0
# 7  03/31/2019 04:00:00 PM                         106.0
# 8  03/31/2019 03:00:00 PM                         130.0
# 9  03/31/2019 02:00:00 PM                         110.0
#
#    Fremont Bridge West Sidewalk
# 0                          10.0
# 1                          14.0
# 2                          15.0
# 3                          31.0
# 4                          58.0
# 5                          89.0
# 6                         106.0
# 7                         105.0
# 8                         121.0
# ...

# %% [markdown]
# ## 2
# **Add columns to the dataframe containing: (3 pt)**
# #### i. The total (East + West) bicycle count

# %%
# Total bicycle count = eEast bicycle count + West bicycle count
bicycle['Total Bicycle Count'] = bicycle['Fremont Bridge East Sidewalk'] + bicycle['Fremont Bridge West Sidewalk']
bicycle.head(10)
# Out:
#                      Date  Fremont Bridge East Sidewalk  \
# 0  03/31/2019 11:00:00 PM                           6.0
# 1  03/31/2019 10:00:00 PM                           7.0
# 2  03/31/2019 09:00:00 PM                          18.0
# 3  03/31/2019 08:00:00 PM                          26.0
# 4  03/31/2019 07:00:00 PM                          30.0
# 5  03/31/2019 06:00:00 PM                          73.0
# 6  03/31/2019 05:00:00 PM                          99.0
# 7  03/31/2019 04:00:00 PM                         106.0
# 8  03/31/2019 03:00:00 PM                         130.0
# 9  03/31/2019 02:00:00 PM                         110.0
#
#    Fremont Bridge West Sidewalk  Total Bicycle Count
# 0                          10.0                 16.0
# 1                          14.0                 21.0
# 2                          15.0                 33.0
# 3                          31.0                 57.0
# 4                          58.0                 88.0
# ...

# %% [markdown]
# #### ii. The hour of the day

# %%
# Convert 'Date' from string to datetime
dates = pd.to_datetime(bicycle['Date'])
# Extract hour from 'Date'
bicycle['Hour'] = dates.dt.hour
bicycle.head(10)
# Out:
#                      Date  Fremont Bridge East Sidewalk  \
# 0  03/31/2019 11:00:00 PM                           6.0
# 1  03/31/2019 10:00:00 PM                           7.0
# 2  03/31/2019 09:00:00 PM                          18.0
# 3  03/31/2019 08:00:00 PM                          26.0
# 4  03/31/2019 07:00:00 PM                          30.0
# 5  03/31/2019 06:00:00 PM                          73.0
# 6  03/31/2019 05:00:00 PM                          99.0
# 7  03/31/2019 04:00:00 PM                         106.0
# 8  03/31/2019 03:00:00 PM                         130.0
# 9  03/31/2019 02:00:00 PM                         110.0
#
#    Fremont Bridge West Sidewalk  Total Bicycle Count  Hour
# 0                          10.0                 16.0    23
# 1                          14.0                 21.0    22
# 2                          15.0                 33.0    21
# 3                          31.0                 57.0    20
# ...

# %% [markdown]
# #### iii. The year

# %%
# Extract year from 'Date'
bicycle['Year'] = dates.dt.year
bicycle.head(10)
# Out:
#                      Date  Fremont Bridge East Sidewalk  \
# 0  03/31/2019 11:00:00 PM                           6.0
# 1  03/31/2019 10:00:00 PM                           7.0
# 2  03/31/2019 09:00:00 PM                          18.0
# 3  03/31/2019 08:00:00 PM                          26.0
# 4  03/31/2019 07:00:00 PM                          30.0
# 5  03/31/2019 06:00:00 PM                          73.0
# 6  03/31/2019 05:00:00 PM                          99.0
# 7  03/31/2019 04:00:00 PM                         106.0
# 8  03/31/2019 03:00:00 PM                         130.0
# 9  03/31/2019 02:00:00 PM                         110.0
#
#    Fremont Bridge West Sidewalk  Total Bicycle Count  Hour  Year
# 0                          10.0                 16.0    23  2019
# 1                          14.0                 21.0    22  2019
# 2                          15.0                 33.0    21  2019
# 3                          31.0                 57.0    20  2019
# ...

# %% [markdown]
# ## 3
# **Create a dataframe with the subset of data from the year 2016 (1 pt)**

# %%
# Subset the bicycle dataframe where the year is 2016
bicycle_2016 = bicycle[bicycle['Year']==2016]
bicycle_2016.head(10)
# Out:
#                          Date  Fremont Bridge East Sidewalk  \
# 19680  12/31/2016 11:00:00 PM                           4.0
# 19681  12/31/2016 10:00:00 PM                           7.0
# 19682  12/31/2016 09:00:00 PM                           4.0
# 19683  12/31/2016 08:00:00 PM                           3.0
# 19684  12/31/2016 07:00:00 PM                           6.0
# 19685  12/31/2016 06:00:00 PM                           4.0
# 19686  12/31/2016 05:00:00 PM                           9.0
# 19687  12/31/2016 04:00:00 PM                          16.0
# 19688  12/31/2016 03:00:00 PM                          19.0
# 19689  12/31/2016 02:00:00 PM                          14.0
#
#        Fremont Bridge West Sidewalk  Total Bicycle Count  Hour  Year
# 19680                           4.0                  8.0    23  2016
# 19681                           8.0                 15.0    22  2016
# 19682                           6.0                 10.0    21  2016
# ...

# %% [markdown]
# ## 4
# **Use pandas + matplotlib to plot the counts by hour. (i.e. hour of the day on the x-axis, total daily counts on the y-axis) (1 pt)**

# %%
# Group bicycle dateframe by 'Hour'
# Compute the sum of total bicycle counts
byHour = bicycle_2016.groupby(['Hour']).sum()
byHour
# Out:
#       Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk  \
# Hour
# 0                           1708.0                        2202.0
# 1                            907.0                        1118.0
# 2                            527.0                         738.0
# 3                            383.0                         398.0
# 4                           1222.0                        1018.0
# 5                           6430.0                        3724.0
# 6                          22317.0                       12565.0
# 7                          60685.0                       28939.0
# 8                          77959.0                       43479.0
# 9                          39863.0                       28503.0
# 10                         19109.0                       15747.0
# 11                         15857.0                       13902.0
# 12                         16364.0                       15250.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Plot the total daily counts by hour of the day
temp = plt.bar(byHour.index, byHour['Total Bicycle Count'])
temp = plt.xlabel('Hour')
temp = plt.ylabel('Counts')
temp = plt.title('Total Daily Counts by Hour of the Day')
plt.show()

# %% [markdown]
# ## 5
# **Use pandas to determine what is (on average) the busiest hour of the day (1 pt)**

# %%
# Group bicycle dateframe by 'Hour'
# Compute average total bicycle counts
# Sort by average total bicycle counts in descending order
# Display the top one 'Hour'
bicycle_2016.groupby(['Hour']).mean().sort_values('Total Bicycle Count', ascending=False).head(1)
# Out:
#       Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk  \
# Hour
# 17                      115.483607                     283.54918
#
#       Total Bicycle Count  Year
# Hour
# 17             399.032787  2016

# %% [markdown]
# Therefore, the busiest hour of the day on average is 5PM.
